# %%
from case_detection import CaseDetector

detector = CaseDetector(inflect=True)

detector.predict("Matkasi {} alkaa.", "Helsinki")
# {'predictions': [{'label': 'All', 'score': 0.87, 'inflected': 'Tampereelle'}],
#  'sentence': 'Matkasi Tampereelle alkaa.'}
# Out:
# {'predictions': [{'label': 'Ill', 'score': 0.6306, 'inflected': 'Helsinkiin'},
#   {'label': 'Ela', 'score': 0.3006, 'inflected': 'Helsingistä'},
#   {'label': 'Ine', 'score': 0.0553, 'inflected': 'Helsingissä'}],
#  'sentence': 'Matkasi Helsinkiin alkaa.'}

# %%
detector.predict("Aion muuttaa {}", "talo")
# Out:
# {'predictions': [{'label': 'Par', 'score': 0.4969, 'inflected': 'taloa'},
#   {'label': 'Ill', 'score': 0.3579, 'inflected': 'taloon'},
#   {'label': 'Nom', 'score': 0.0528, 'inflected': 'talo'},
#   {'label': 'Gen', 'score': 0.0527, 'inflected': 'talon'}],
#  'sentence': 'Aion muuttaa taloa'}
